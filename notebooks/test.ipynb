# %%
from tabarena.benchmark.task.openml import OpenMLTaskWrapper
from tabarena.nips2025_utils.fetch_metadata import load_task_metadata
import openml
import pandas as pd

metadata = load_task_metadata()
dataset_names = metadata.sort_values("n_samples_train_per_fold").name.tolist()

dataset_name = dataset_names[36]

dataset_name = "qsar-biodeg"

print(f"Loading dataset {dataset_name}")


tid = int(metadata.loc[metadata.name == dataset_name, "tid"].iloc[0])
task = OpenMLTaskWrapper(openml.tasks.get_task(tid))

fold = 0
repeat = 0
sample = None

X, y, X_test, y_test = task.get_train_test_split(fold=fold, repeat=repeat)
target_type = task.problem_type
# Out:
# Loading dataset qsar-biodeg

# %%
from tabarena.nips2025_utils.tabarena_context import TabArenaContext

ta_context = TabArenaContext()
ta_results = pd.concat(
    [ta_context.load_hpo_results(i) for i in ta_context.methods if "AutoGluon" not in i]
).reset_index(drop=True)
ta_results
# Out:
#             dataset  fold                 method  metric_error  time_train_s  \
# 0        APSFailure     0          CAT (default)      0.006103     96.988604
# 1        APSFailure     1          CAT (default)      0.009555    119.110543
# 2        APSFailure     2          CAT (default)      0.007709     94.685867
# 3        APSFailure     3          CAT (default)      0.013824    107.629186
# 4        APSFailure     4          CAT (default)      0.005124    116.515858
# ...             ...   ...                    ...           ...           ...
# 49609  wine_quality     4  TABPFN-V2.6 (default)      0.559790     14.136633
# 49610  wine_quality     5  TABPFN-V2.6 (default)      0.590978     13.466732
# 49611  wine_quality     6  TABPFN-V2.6 (default)      0.593622     14.143197
# 49612  wine_quality     7  TABPFN-V2.6 (default)      0.612643     13.833819
# 49613  wine_quality     8  TABPFN-V2.6 (default)      0.586095     13.984481
#
#        time_infer_s   metric problem_type  metric_error_val imputed  \
# 0          0.493216  roc_auc       binary          0.009566   False
# 1          0.665473  roc_auc       binary          0.006697   False
# 2          0.519010  roc_auc       binary          0.007477   False
# 3          0.173889  roc_auc       binary          0.007113   False
# 4          0.181812  roc_auc       binary          0.009647   False
# ...             ...      ...          ...               ...     ...
# 49609      0.651172     rmse   regression          0.618513     NaN
# 49610      0.661466     rmse   regression          0.608002     NaN
# 49611      0.656172     rmse   regression          0.605624     NaN
# 49612      0.651727     rmse   regression          0.600795     NaN
# 49613      0.651858     rmse   regression          0.598343     NaN
#
#       impute_method method_type method_subtype  config_type method_metadata  \
# 0              None      config        default          CAT            None
# 1              None      config        default          CAT            None
# 2              None      config        default          CAT            None
# 3              None      config        default          CAT            None
# 4              None      config        default          CAT            None
# ...             ...         ...            ...          ...             ...
# 49609           NaN      config        default  TABPFN-V2.6             NaN
# 49610           NaN      config        default  TABPFN-V2.6             NaN
# 49611           NaN      config        default  TABPFN-V2.6             NaN
# 49612           NaN      config        default  TABPFN-V2.6             NaN
# 49613           NaN      config        default  TABPFN-V2.6             NaN
#
#            ta_name             ta_suite
# 0         CatBoost  tabarena-2025-06-12
# 1         CatBoost  tabarena-2025-06-12
# 2         CatBoost  tabarena-2025-06-12
# 3         CatBoost  tabarena-2025-06-12
# 4         CatBoost  tabarena-2025-06-12
# ...            ...                  ...
# 49609  TabPFN-v2.6  tabarena-2026-03-18
# 49610  TabPFN-v2.6  tabarena-2026-03-18
# 49611  TabPFN-v2.6  tabarena-2026-03-18
# 49612  TabPFN-v2.6  tabarena-2026-03-18
# 49613  TabPFN-v2.6  tabarena-2026-03-18
#
# [49614 rows x 17 columns]
